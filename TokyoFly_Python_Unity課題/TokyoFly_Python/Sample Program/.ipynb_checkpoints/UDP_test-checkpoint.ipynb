# %%
from socket import *

class udp_server:
    def __init__(self):
        # 送信側IP
        SrcIP = "127.0.0.1"    # localhost
        # 送信側ポート番号
        SrcPort = 11111
        # 送信側アドレスをtupleに格納
        self.SrcAddr = (SrcIP, SrcPort)

        # 受信側アドレスの設定
        # 受信側IP
        DstIP = "127.0.0.1"
        # 受信側ポート番号
        DstPort = 22222
        # 受信側アドレスをtupleに格納
        self.DstAddr = (DstIP, DstPort)
        
        # 受信時のバッファサイズ
        self.buffer_size = 4092

        # ソケット作成
        self.udpClntSock = socket(AF_INET, SOCK_DGRAM)
        # 送信側アドレスでソケットを設定
        self.udpClntSock.bind(self.SrcAddr)
        
    
    def __delete__(self):
        del self.udpClntSock
        
        
    def sendString(self, data):
        # バイナリに変換
        data = data.encode('utf-8')

        # 受信側アドレスに送信
        self.udpClntSock.sendto(data, self.DstAddr)
        
    def sendInt(self, intVal):
        data = intVal.to_bytes(4, 'little')
        self.udpClntSock.sendto(data, self.DstAddr)
        
    def receive(self):
        data = self.udpClntSock.recv(self.buffer_size)
        return data

# %%
udp_sample = udp_server()

# %%
while (True):
    data = udp_sample.receive()
    intVal = int.from_bytes(data, 'little')
    print(intVal)
    udp_sample.sendInt(intVal)

# %%
import struct
while (True):
    data = udp_sample.receive()
    floatVal = struct.unpack('<<f', data)
    print(floatVal)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [3], in <cell line: 3>()
#       2 while (True):
#       3     data = udp_sample.receive()
# ----> 4     floatVal = struct.unpack('<f', data)
#       5     print(floatVal)
#
# error: unpack requires a buffer of 4 bytes

# %%
del udp_sample
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 del udp_sample
#
# NameError: name 'udp_sample' is not defined
